# %% [markdown]
# # PERFORMANCE MANAGEMENT
# ---

# %% [markdown]
# # Accountability
# ---
#
# * Give feedback
# * Stay connected
# * Collect samples of their work

# %% [markdown]
# # Barriers To Performance
# ---
#
# * Resources
# * Time
# * Threats

# %% [markdown]
# # Manager Mistakes
# ---
#
# * Arriving late
# * Arriving unprepared
# * Cognitive errors
# * Making promises
# * Allowing negativity
# * Linking pay to the review process

# %% [markdown]
# # Meeting Preparation
# ---
#
# Three weeks prior:
#
#  * Send final emails
#  * Reach out to answer questions
#
# Two weeks prior:
#
#  * Reserve a room for the meetings, preferably in a neutral location
#
# One week prior:
#
#  * Consider possible reactions
#
# Pre-meeting checklist:
#
#  * Arrive 30m early
#  * Set up the room
#  * Review your notes and agenda
#  * Check for needed documents
#  * Hold all calls
#
# Productive meetings:
#
#  * Be prepared for interruptions
#  * Stick to your agenda
#  * Listen
#  * Maintain focus
#
# Meeting closing:
#
#  * Thank them for their time
#  * Confirm any agreed follow-up conversations
#  * Get a signature

# %% [markdown]
# # Performance Improvement Plan
# ---
#
# A performance improvement plan is a formal document that details the specific skills and behaviors that have been identified as problematic and a description of exactly how they should improve over the course of several months.
#
# Whether you're targeting hard skills or soft, this type of formal approach to feedback is often the strong signal needed, to get someone back on track, and this approach won't surprise them. If you've been monitoring performance and giving normal feedback as needed, this escalation shouldn't surprise them at all.
#
# ## Effective Performance Improvement Plans
#
#  * Delivered in private
#  * Explicitly describe problematic skills and behavior
#  * Detail improvements that must be made
#  * Suggest specific training and resources
#  * Clear everything with your boss and HR
#  * Proofread the document
#  * Get the employee's signature

# %% [markdown]
# # Performance Review
# ---
#
# Ensure that your evaluation is accurate and free of well-known biases:
#
#  * Maintain process integrity
#  * Be prepared to deal with emotions
#  * Make sure feedback is accurate and helpful
#
# Make time for a thorough review:
#
#  * Two hours per employee
#  * Two to three weeks prior to the meeting
#
# Review the data:
#
#  * Your notes
#  * Attendance records
#  * Work samples
#  * Employee's self-review
#  * 360-degree feedback
#  * Third-party feedback
#
# Create a first draft:
#
#  * Start by writing your narrative statements for each part
#  * Compare your honest, raw comments, to the summaries provided by other raters
#  * Do a review of your narrative
#  * Do a GAP analysis between your analysis and the analysis made by others, as well as the employee self-assessment
#  * Take note of the differences found and decide what positions you'll be taking and prepare to explain those in your review
#  * Carefully select the language you've used, e.g. avoid emotional words or tone, and be very specific. Be clear, but never extreme
#  * Frame things as opportunities, not judgements, whenever possible
#  * Instead of current evaluation, focus on their future development
#
# Create the final draft:
#
#  * It's time to really polish your work and take it from good to really useful for your employees
#  * Do any necessary breaks and edits (considering technical, accuracy, developmental, and distribution aspects).

# %% [markdown]
# # SMART
# ---
#
# SMART is an acronym that stands for Specific, Measurable, Achievable, Relevant and Time-based. Each element of the SMART framework works together to create a goal that is carefully planned, clear and trackable.
#
# You may have set goals in your past that were difficult to achieve because they were too vague, aggressive or poorly framed. Working toward a poorly-crafted goal can feel daunting and unachievable. Creating SMART goals can help solve these problems. Whether you’re setting personal or professional goals, using the SMART goal framework can establish a strong foundation for achieving success.
#
# ## Specific
#
# Goals that are specific have a significantly greater chance of being accomplished. To make a goal specific, the five “W” questions must be considered:
#
# * Who: Who is involved in this goal?
# * What: What do I want to accomplish?
# * Where: Where is this goal to be achieved?
# * When: When do I want to achieve this goal?
# * Why: Why do I want to achieve this goal?
#
# For example, a general goal would be “I want to get in shape.” A more specific goal would be “I want to obtain a gym membership at my local community center and work out four days a week to be healthier.”
#
# ## Measurable
#
# A SMART goal must have criteria for measuring progress. If there are no criteria, you will not be able to determine your progress and if you are on track to reach your goal. To make a goal measurable, ask yourself:
#
# * How many/much?
# * How do I know if I have reached my goal?
# * What is my indicator of progress?
#
# For example, building on the specific goal above: I want to obtain a gym membership at my local community center and work out four days a week to be healthier. Every week, I will aim to lose one pound of body fat.
#
# ## Achievable
#
# A SMART goal must be achievable and attainable. This will help you figure out ways you can realize that goal and work towards it. The achievability of the goal should be stretched to make you feel challenged, but defined well enough that you can actually achieve it. Ask yourself:
#
# Do I have the resources and capabilities to achieve the goal? If not, what am I missing?
# Have others done it successfully before?
#
# ## Realistic
#
# A SMART goal must be realistic in that the goal can be realistically achieved given the available resources and time. A SMART goal is likely realistic if you believe that it can be accomplished. Ask yourself:
#
# * Is the goal realistic and within reach?
# * Is the goal reachable, given the time and resources?
# * Are you able to commit to achieving the goal?
#
# ## Timely
#
# A SMART goal must be time-bound in that it has a start and finish date. If the goal is not time-constrained, there will be no sense of urgency and, therefore, less motivation to achieve the goal. Ask yourself:
#
# * Does my goal have a deadline?
# * By when do you want to achieve your goal?
#
# For example, building on the goal above: On August 1, I will obtain a gym membership at my local community center. In order to be healthier, I will work out four days a week. Every week, I will aim to lose one pound of body fat. By the end of August, I will have realized my goal if I lose four pounds of fat over the course of the month.
#
# ![SMART](images\smart.png "SMART")
